# %% [markdown]
# # 1.- Carga de librerías

# %%
import pandas as pd

# %% [markdown]
# # 2.- Carga de datos.

# %% [markdown]
# Parámetros de la carga:

# %% [markdown]
# ## 2.1.- Cargamos el fichero de hogares

# %%
def Carga_1_archivoHogares2016(Origen):
    df_hogares=pd.read_fwf(Origen,
               header=None,
               names = ['ANOENC','NUMERO','CCAA','NUTS1','CAPROV',
                        'TAMAMU','DENSIDAD','CLAVE','CLATEO','FACTOR',
                        'NMIEMB','TAMANO','NMIEMSD','NMIEMHU','NMIEMIN',
                        'NMIEM1','NMIEM2','NMIEM3','NMIEM4','NMIEM5',
                        'NMIEM6','NMIEM7','NMIEM8','NMIEM9','NMIEM10',
                        'NMIEM11','NMIEM12','NMIEM13','NUMACTI','NUMINACTI',
                        'NUMOCUP','NUMNOCUP','NUMESTU','NUMNOESTU','NNINOSD',
                        'NHIJOSD','UC1','UC2','PF2TEO','PF2RECO',
                        'TIPHOGAR1','TIPHOGAR2','TIPHOGAR3','TIPHOGAR4','TIPHOGAR5',
                        'TIPHOGAR6','TIPHOGAR7','TIPHOGAR8','TIPHOGAR9','TIPHOGAR10',
                        'TIPHOGAR11','SITUOCUHOG','SITUACTHOG','NORDENSP','EDADSP',
                        'SEXOSP','PAISNACSP','NACIONASP','PAISSP','SITURESSP',
                        'ECIVILLEGALSP','NORDENCOSP','UNIONSP','CONVIVENCIASP','NORDENPASP',
                        'PAISPADRESP','NORDENMASP','PAISMADRESP','ESTUDIOSSP','ESTUDREDSP',
                        'SITUACTSP','SITUREDSP','OCUSP','JORNADASP','PERCEPSP',
                        'IMPEXACPSP','INTERINPSP','TRABAJO','OCUPA','OCUPARED',
                        'ACTESTB','ACTESTBRED','SITPROF','SECTOR','CONTRATO',
                        'TIPOCONT','SITSOCI','SITSOCIRE','REGTEN','TIPOEDIF',
                        'ZONARES','TIPOCASA','NHABIT','ANNOCON','SUPERF',
                        'AGUACALI','FUENAGUA','CALEF','FUENCALE','DISPOSIOV',
                        'NUMOVD','REGTENV1','MESESV1','DIASV1','AGUACV1',
                        'FUENACV1','CALEFV1','FUENCAV1','REGTENV2','MESESV2',
                        'DIASV2','AGUACV2','FUENACV2','CALEFV2','FUENCAV2',
                        'REGTENV3','MESESV3','DIASV3','AGUACV3','FUENACV3',
                        'CALEFV3','FUENCAV3','REGTENV4','MESESV4','DIASV4',
                        'AGUACV4','FUENACV4','CALEFV4','FUENCAV4','REGTENV5',
                        'MESESV5','DIASV5','AGUACV5','FUENACV5','CALEFV5',
                        'FUENCAV5','REGTENV6','MESESV6','DIASV6','AGUACV6',
                        'FUENACV6','CALEFV6','FUENCAV6','REGTENV7','MESESV7',
                        'DIASV7','AGUACV7','FUENACV7','CALEFV7','FUENCAV7',
                        'REGTENV8','MESESV8','DIASV8','AGUACV8','FUENACV8',
                        'CALEFV8','FUENCAV8','REGTENV9','MESESV9','DIASV9',
                        'AGUACV9','FUENACV9','CALEFV9','FUENCAV9','GASTOT',
                        'IMPUTGAS','GASTMON','GASTNOM1','GASTNOM2','GASTNOM3',
                        'GASTNOM4','CAPROP','CAJENA','PENSIO','DESEM',
                        'OTRSUB','RENTAS','OTROIN','FUENPRIN','FUENPRINRED',
                        'IMPEXAC','INTERIN','NUMPERI','COMIMH','COMISD',
                        'COMIHU','COMIINV','COMITOT'],
               widths=[4,5,2,1,1,
                        1,1,1,1,11,
                        2,1,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,3,3,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        5,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,1,2,
                        2,2,2,2,3,
                        2,2,2,2,1,
                        1,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,16,
                        5,16,13,13,13,
                        13,2,2,2,2,
                        2,2,2,2,2,
                        5,2,2,3,3,
                        3,3,3]
                      )
    return df_hogares

# %%
def Carga_1_archivoHogares(Origen):
    df_hogares=pd.read_fwf(Origen,
               header=None,
               names = ['ANOENC','NUMERO','CCAA','NUTS1','CAPROV',
                        'TAMAMU','DENSIDAD','CLAVE','CLATEO','FACTOR',
                        'NMIEMB','TAMANO','NMIEMSD','NMIEMHU','NMIEMIN',
                        'NMIEM1','NMIEM2','NMIEM3','NMIEM4','NMIEM5',
                        'NMIEM6','NMIEM7','NMIEM8','NMIEM9','NMIEM10',
                        'NMIEM11','NMIEM12','NMIEM13','NUMACTI','NUMINACTI',
                        'NUMOCUP','NUMNOCUP','NUMESTU','NUMNOESTU','NNINOSD',
                        'NHIJOSD','UC1','UC2','PF2TEO','PF2RECO',
                        'TIPHOGAR1','TIPHOGAR2','TIPHOGAR3','TIPHOGAR4','TIPHOGAR5',
                        'TIPHOGAR6','TIPHOGAR7','TIPHOGAR8','TIPHOGAR9','TIPHOGAR10',
                        'TIPHOGAR11','SITUOCUHOG','SITUACTHOG','NORDENSP','EDADSP',
                        'SEXOSP','PAISNACSP','NACIONASP','PAISSP','SITURESSP',
                        'ECIVILLEGALSP','NORDENCOSP','UNIONSP','CONVIVENCIASP','NORDENPASP',
                        'PAISPADRESP','NORDENMASP','PAISMADRESP','ESTUDIOSSP','ESTUDREDSP',
                        'SITUACTSP','SITUREDSP','OCUSP','JORNADASP','PERCEPSP',
                        'IMPEXACPSP','INTERINPSP','TRABAJO','OCUPA','OCUPARED',
                        'ACTESTB','ACTESTBRED','SITPROF','SECTOR','CONTRATO',
                        'TIPOCONT','SITSOCI','SITSOCIRE','REGTEN','TIPOEDIF',
                        'ZONARES','TIPOCASA','NHABIT','ANNOCON','SUPERF',
                        'AGUACALI','FUENAGUA','CALEF','FUENCALE','DISPOSIOV',
                        'NUMOVD','REGTENV1','MESESV1','DIASV1','AGUACV1',
                        'FUENACV1','CALEFV1','FUENCAV1','REGTENV2','MESESV2',
                        'DIASV2','AGUACV2','FUENACV2','CALEFV2','FUENCAV2',
                        'REGTENV3','MESESV3','DIASV3','AGUACV3','FUENACV3',
                        'CALEFV3','FUENCAV3','REGTENV4','MESESV4','DIASV4',
                        'AGUACV4','FUENACV4','CALEFV4','FUENCAV4','REGTENV5',
                        'MESESV5','DIASV5','AGUACV5','FUENACV5','CALEFV5',
                        'FUENCAV5','REGTENV6','MESESV6','DIASV6','AGUACV6',
                        'FUENACV6','CALEFV6','FUENCAV6','REGTENV7','MESESV7',
                        'DIASV7','AGUACV7','FUENACV7','CALEFV7','FUENCAV7',
                        'REGTENV8','MESESV8','DIASV8','AGUACV8','FUENACV8',
                        'CALEFV8','FUENCAV8','REGTENV9','MESESV9','DIASV9',
                        'AGUACV9','FUENACV9','CALEFV9','FUENCAV9','GASTOT',
                        'IMPUTGAS','GASTMON','GASTNOM1','GASTNOM2','GASTNOM3',
                        'GASTNOM4','CAPROP','CAJENA','PENSIO','DESEM',
                        'OTRSUB','RENTAS','OTROIN','FUENPRIN','FUENPRINRED',
                        'IMPEXAC','INTERIN','NUMPERI','COMIMH','COMISD',
                        'COMIHU','COMIINV','COMITOT'],
               widths=[4,5,2,1,1,
                        1,1,1,1,11,
                        2,1,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,3,3,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        5,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,1,2,
                        2,2,2,2,3,
                        2,2,2,2,1,
                        1,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,2,
                        2,2,2,2,16,
                        5,16,13,13,13,
                        13,2,2,2,2,
                        2,2,2,2,2,
                        5,2,2,3,3,
                        3,3,3]
                      )
    return df_hogares

# %%
def CreaDFhogares(RutaOrigen,FicheroOrigen):
    Origen=RutaOrigen+'\\'+FicheroOrigen
    df_hogares=Carga_1_archivoHogares(Origen)
    return df_hogares

# %%
def AnexaDFhogares(df_hogares_total,RutaOrigen,FicheroOrigen):
    Origen=RutaOrigen+'\\'+FicheroOrigen
    df_hogares=Carga_1_archivoHogares(Origen)
    df_hogares_total=pd.concat([df_hogares_total,df_hogares],ignore_index=True)
    return df_hogares_total

# %%
RutaOrigen=r'C:\Users\javi_\Google Drive\ModelOfSpain\01_Origenes\EncuestaPresupuestosFamiliares2019'
FicheroOrigen=r'Fichero de usuario de hogar a2019IMP.txt'
df_hogares=CreaDFhogares(RutaOrigen,FicheroOrigen)

# %%
RutaOrigen=r'C:\Users\javi_\Google Drive\ModelOfSpain\01_Origenes\EncuestaPresupuestosFamiliares2018'
FicheroOrigen=r'Fichero de usuario de hogar a2018IMP.txt'
df_hogares=AnexaDFhogares(df_hogares,RutaOrigen,FicheroOrigen)

# %%
RutaOrigen=r'C:\Users\javi_\Google Drive\ModelOfSpain\01_Origenes\EncuestaPresupuestosFamiliares2017'
FicheroOrigen=r'Fichero de usuario de hogar a2017.txt'
df_hogares=AnexaDFhogares(df_hogares,RutaOrigen,FicheroOrigen)

# %%
RutaOrigen=r'C:\Users\javi_\Google Drive\ModelOfSpain\01_Origenes\EncuestaPresupuestosFamiliares2016'
FicheroOrigen=r'Fichero de usuario de hogar a2016.txt'
df_hogares=AnexaDFhogares(df_hogares,RutaOrigen,FicheroOrigen)

# %%
RutaOrigen=r'C:\Users\javi_\Google Drive\ModelOfSpain\01_Origenes\EncuestaPresupuestosFamiliares2020'
FicheroOrigen=r'Fichero de usuario de hogar a2020IMPAJUSTE.txt'
df_hogares=AnexaDFhogares(df_hogares,RutaOrigen,FicheroOrigen)

# %%
df_hogares['ANOENC'].value_counts()
# Out:
# 2017    22043
# 2016    22011
# 2018    21395
# 2019    20817
# 2020    19170
# Name: ANOENC, dtype: int64

# %%
df_hogares.shape
# Out:
# (105436, 188)

# %%
df_hogares['FACTOR']=df_hogares['FACTOR']/pow(10,6)
df_hogares['UC1']=df_hogares['UC1']/pow(10,1)
df_hogares['UC2']=df_hogares['UC2']/pow(10,1)
df_hogares['GASTOT']=df_hogares['GASTOT']/pow(10,2)
df_hogares['IMPUTGAS']=df_hogares['IMPUTGAS']/pow(10,2)
df_hogares['GASTMON']=df_hogares['GASTMON']/pow(10,2)
df_hogares['GASTNOM1']=df_hogares['GASTNOM1']/pow(10,2)
df_hogares['GASTNOM2']=df_hogares['GASTNOM2']/pow(10,2)
df_hogares['GASTNOM3']=df_hogares['GASTNOM3']/pow(10,2)
df_hogares['GASTNOM4']=df_hogares['GASTNOM4']/pow(10,2)

# %%
df_hogares.head(20)
# Out:
#     ANOENC  NUMERO  CCAA  NUTS1  CAPROV  TAMAMU  DENSIDAD  CLAVE  CLATEO  \
# 0     2019       1     1      6       1       1         1      2       2
# 1     2019       2    13      3       6       1         1      1       2
# 2     2019       3    15      2       6       4         2      1       2
# 3     2019       4    16      2       6       4         1      1       1
# 4     2019       5     3      1       6       4         3      2       2
# 5     2019       6    18      6       1       2         1      1       1
# 6     2019       7    13      3       6       1         1      1       2
# 7     2019       8    10      5       1       1         1      1       2
# 8     2019       9    10      5       6       3         2      1       1
# 9     2019      10     3      1       6       2         1      2       2
# 10    2019      11     7      4       1       1         1      1       1
# 11    2019      12     9      5       6       4         2      2       2
# ...

# %% [markdown]
# Verificamos que el número de hogares totales es de unos 18,6 millones

# %%
df_hogares['FACTOR'].sum()/pow(10,6)
# Out:
# 93.171506756252

# %%
df_hogares[['ANOENC','FACTOR']].groupby('ANOENC').sum()/pow(10,6)
# Out:
#            FACTOR
# ANOENC
# 2016    18.444023
# 2017    18.512537
# 2018    18.627677
# 2019    18.742156
# 2020    18.845114

# %% [markdown]
# Y que los habitantes que se recogen son unos 46 millones.

# %%
df_hogares['Poblacion']=df_hogares['FACTOR']*df_hogares['NMIEMB']
df_hogares['Poblacion'].sum()/pow(10,6)
# Out:
# 231.89546609061395

# %%
df_hogares[['ANOENC','Poblacion']].groupby('ANOENC').sum()/pow(10,6)
# Out:
#         Poblacion
# ANOENC
# 2016    45.977771
# 2017    46.079738
# 2018    46.296324
# 2019    46.645649
# 2020    46.895985

# %% [markdown]
# ### Vamos a utilizar una función para traducir los valores

# %%
def Traduce(df,diccionario,CampoOrigen,CampoDestino):
    Filas=df.shape[0]
    for i in range(Filas):
        entero=df.loc[i,CampoOrigen]
        if entero is not None:
            cadena=diccionario[entero]
            df.loc[i,CampoDestino]=cadena
    print(df[CampoDestino].value_counts(1))

# %% [markdown]
# ### Traducimos las CCAA

# %%
CCAAdict = {
    1:  "Andalucía",
    2:  "Aragón",
    3:  "Asturias",
    4:  "Baleares",
    5:  "Canarias",
    6:  "Cantabria",
    7:  "Castilla y León",
    8:  "Castilla La Mancha",
    9:  "Cataluña",
    10: "Valencia",
    11: "Extremadura",
    12: "Galicia",
    13: "Madrid",
    14: "Murcia",
    15: "Navarra",
    16: "País Vasco",
    17: "La Rioja",
    18: "Ceuta",
    19: "Melilla"
}

# %%
Traduce(df_hogares,CCAAdict,'CCAA','Comunidad')
# Out:
# Andalucía             0.108739
# País Vasco            0.103504
# Cataluña              0.090301
# Valencia              0.078967
# Madrid                0.074699
# Castilla y León       0.065205
# Galicia               0.062607
# Castilla La Mancha    0.053824
# Canarias              0.045639
# Aragón                0.045601
# Extremadura           0.044302
# Murcia                0.043894
# Asturias              0.041532
# Cantabria             0.035633
# Navarra               0.033565
# La Rioja              0.031545
# Baleares              0.029724
# Melilla               0.005510
# Ceuta                 0.005207
# Name: Comunidad, dtype: float64

# %% [markdown]
# ### Traduciomos NUTS1

# %%
NUTS1dict = {
1: 'NorOeste',
2: 'NorEste',
3: 'Madrid',
4: 'Centro',
5: 'Este',
6: 'Sur',
7: 'Canarias'
}

# %%
Traduce(df_hogares,NUTS1dict,'NUTS1','NUTS1')
# Out:
# NorEste     0.214215
# Este        0.198993
# Sur         0.163350
# Centro      0.163331
# NorOeste    0.139772
# Madrid      0.074699
# Canarias    0.045639
# Name: NUTS1, dtype: float64

# %% [markdown]
# ### Traducimos CAPROV

# %%
CAPROVdict={
    1: 'Capital',
    6: 'No capital'
}

# %%
Traduce(df_hogares,CAPROVdict,'CAPROV','CapitalProvincia')
# Out:
# No capital    0.658466
# Capital       0.341534
# Name: CapitalProvincia, dtype: float64

# %% [markdown]
# ### Traducimos TAMAMU

# %%
TAMAMUdict={
    1: '100.000 o más',
    2: ' 50.000 a 100.000',
    3: ' 20.000 a 50.000',
    4: ' 10.000 a 20.000',
    5: ' 10.000 o menos'
}

# %%
Traduce(df_hogares,TAMAMUdict,'TAMAMU','HabitantesMunicipio')
# Out:
# 100.000 o más        0.375507
#  10.000 o menos      0.237860
#  20.000 a 50.000     0.154501
#  50.000 a 100.000    0.125109
#  10.000 a 20.000     0.107022
# Name: HabitantesMunicipio, dtype: float64

# %% [markdown]
# ### Traducimos DENSIDAD

# %%
DENSIDADdict={
    1: 'Zona densamente poblada',
    2: 'Zona intermedia',
    3: 'Zona diseminada'  
}

# %%
Traduce(df_hogares,DENSIDADdict,'DENSIDAD','DensidadPoblacion')
# Out:
# Zona densamente poblada    0.472524
# Zona diseminada            0.282598
# Zona intermedia            0.244878
# Name: DensidadPoblacion, dtype: float64

# %% [markdown]
# ### Traducimos TIPHOGAR1

# %%
TIPHOGAR1dict={
    1: 'Una persona de 65 o más',
    2: 'Una persona de 30 a 64',
    3: 'Una persona de menos de 30',
    4: 'Un adulto con niños menores de 16',
    5: 'Pareja sin hijos, al menos uno 65 o más',
    6: 'Pareja sin hijos, ambos menos de 65',
    7: 'Pareja con un hijo menor de 16',
    8: 'Pareja con dos hijos menores de 16',
    9: 'Pareja con tres o más hijos menores de 16',
    10: 'Padre o madre solo, al menos un hijo de 16 o más',
    11: 'Pareja con al menos un hijo de 16 o más',
    12: 'Otros hogares' 
}

# %%
Traduce(df_hogares,TIPHOGAR1dict,'TIPHOGAR1','TipoHogar')
# Out:
# Pareja con al menos un hijo de 16 o más             0.206172
# Pareja sin hijos, al menos uno 65 o más             0.130563
# Pareja sin hijos, ambos menos de 65                 0.113111
# Una persona de 30 a 64                              0.099283
# Una persona de 65 o más                             0.090548
# Pareja con dos hijos menores de 16                  0.087314
# Otros hogares                                       0.080589
# Pareja con un hijo menor de 16                      0.077213
# Padre o madre solo, al menos un hijo de 16 o más    0.075913
# Un adulto con niños menores de 16                   0.019367
# Pareja con tres o más hijos menores de 16           0.014843
# Una persona de menos de 30                          0.005084
# Name: TipoHogar, dtype: float64

# %% [markdown]
# ### SITUOCUHOG

# %%
SITUOCUHOGdict={
    1: 'Sustentador principal y cónyuge ocupados, al menos otro ocupado',
    2: 'Sustentador principal y cónyuge ocupados, no más ocupados',
    3: 'Sustentador principal o cónyuge ocupado, otro ocupado',
    4: 'Sustentador principal o cónyuge ocupado, al menos otros dos ocupados',
    5: 'Sustentador principal o cónyuge ocupado, no más ocupados',
    6: 'Ni sustentador principal ni cónyuge ocupado, otro ocupado',
    7: 'Ni sustentador principal ni cónyuge ocupados, al menos otros dos ocupados',
    8: 'Ningún ocupado en el hogar',
    -9: 'No consta'
}

# %%
Traduce(df_hogares,SITUOCUHOGdict,'SITUOCUHOG','SituacionHogar')
# Out:
# Ningún ocupado en el hogar                                                   0.344218
# Sustentador principal y cónyuge ocupados, no más ocupados                    0.241758
# No consta                                                                    0.165788
# Sustentador principal o cónyuge ocupado, no más ocupados                     0.162165
# Sustentador principal y cónyuge ocupados, al menos otro ocupado              0.026120
# Ni sustentador principal ni cónyuge ocupado, otro ocupado                    0.025817
# Sustentador principal o cónyuge ocupado, otro ocupado                        0.024603
# Sustentador principal o cónyuge ocupado, al menos otros dos ocupados         0.004922
# Ni sustentador principal ni cónyuge ocupados, al menos otros dos ocupados    0.004609
# Name: SituacionHogar, dtype: float64

# %% [markdown]
# ### SEXOSP

# %%
SEXOSPdict={
    1: 'Hombre',
    6: 'Mujer',
    -9: 'No consta'    
}

# %%
Traduce(df_hogares,SEXOSPdict,'SEXOSP','SexoSustentadorPrincipal')
# Out:
# Hombre    0.672275
# Mujer     0.327725
# Name: SexoSustentadorPrincipal, dtype: float64

# %% [markdown]
# ### PAISNACSP

# %%
PAISNACSPdict={
    1: 'España',
    2: 'UE',
    3: 'Europa, no UE',
    4: 'No Europa',
    -9: 'No consta'
}

# %%
Traduce(df_hogares,PAISNACSPdict,'PAISNACSP','PaisNacimientoSustentador')
# Out:
# España           0.915076
# No Europa        0.057978
# UE               0.023208
# Europa, no UE    0.003737
# Name: PaisNacimientoSustentador, dtype: float64

# %% [markdown]
# ### ESTUDIOSSP

# %%
ESTUDIOSSPdict={
    1: 'No sabe leer o escribir o menos de 5 años en escuela',
    2: 'Educación primaria completa o escuela al menos 5 años',
    3: 'ESO, EGB o Bachiller Elemental (con titulo o cursados, al menos, 3º, 8º o 4º respectivamente) y similares',
    4: 'Bachiller, BUP, COU, Bachiller Superior, FP de Grado Medio, FP Básica y otros estudios de grado medio',
    5: 'FP de Grado Superior, FPII y equivalentes',
    6: 'Grado de 240 ECTS, Diplomatura, Arquitectura e Ingeniería Técnicas y equivalentes.',
    7: 'Grado de más de 240 ECTS, Licenciatura, Arquitectura, Ingeniería, másteres, especialidad en Ciencias de la Salud y equivalentes.',
    8: 'Doctorado universitario.'
}

# %%
Traduce(df_hogares,ESTUDIOSSPdict,'ESTUDIOSSP','EstudiosSustentadorPrincipal')
# Out:
# ESO, EGB o Bachiller Elemental (con titulo o cursados, al menos, 3º, 8º o 4º respectivamente) y similares                           0.295355
# Bachiller, BUP, COU, Bachiller Superior, FP de Grado Medio, FP Básica y otros estudios de grado medio                               0.182556
# Educación primaria completa o escuela al menos 5 años                                                                               0.162468
# Grado de más de 240 ECTS, Licenciatura, Arquitectura, Ingeniería, másteres, especialidad en Ciencias de la Salud y equivalentes.    0.133446
# FP de Grado Superior, FPII y equivalentes                                                                                           0.099292
# Grado de 240 ECTS, Diplomatura, Arquitectura e Ingeniería Técnicas y equivalentes.                                                  0.087693
# ...

# %% [markdown]
# ### ESTUDREDSP

# %%
ESTUDREDSPdict={
    1: 'Menos que primera etapa Educación Secundaria.',
    2: 'Primera etapa Educación secundaria',
    3: 'Segunda etapa Educación secundaria',
    4: 'Educación superior'   
}

# %%
Traduce(df_hogares,ESTUDREDSPdict,'ESTUDREDSP','EstudiosSustentadorPrincipal_redux')
# Out:
# Educación superior                               0.329821
# Primera etapa Educación secundaria               0.295355
# Menos que primera etapa Educación Secundaria.    0.192268
# Segunda etapa Educación secundaria               0.182556
# Name: EstudiosSustentadorPrincipal_redux, dtype: float64

# %% [markdown]
# ### SITUACTSP

# %%
SITUACTSPdict={
    1: 'Trabajando',
    2: 'De baja',
    3: 'Parado/a',
    4: 'Jubilado/a',
    5: 'Estudiante',
    6: 'Labores del hogar',
    7: 'Incapacidad laboral per.',
    8: 'Otra inactividad'
}

# %%
Traduce(df_hogares,SITUACTSPdict,'SITUACTSP','SitLaboralSustentadorPrincipal')
# Out:
# Trabajando                  0.545601
# Jubilado/a                  0.299717
# Parado/a                    0.059809
# Labores del hogar           0.044387
# De baja                     0.027619
# Incapacidad laboral per.    0.015185
# Otra inactividad            0.006829
# Estudiante                  0.000854
# Name: SitLaboralSustentadorPrincipal, dtype: float64

# %% [markdown]
# ### OCUPA

# %%
OCUPAdict={
    1: 'Directores y gerentes',
    2: 'Técnicos y profesionales científicos e intelectuales',
    3: 'Técnicos y profesionales de apoyo',
    4: 'Empleados contables, administrativos y otros empleados de oficina',
    5: 'Trabajadores de los servicios de restauración, personales, protección y vendedores',
    6: 'Trabajadores cualificados en el sector agrícola, ganadero, forestal y pesquero',
    7: 'Artesanos y trabajadores cualificados de las industrias manufactureras y la construcción (excepto operadores de instalaciones y maquinaria)',
    8: 'Operadores de instalaciones y maquinaria, y montadores',
    9: 'Ocupaciones elementales',
    0: 'Ocupaciones militares',
    -9: 'No consta'
}

# %%
def TraduceAunqueHayaNaNs(df,diccionario,CampoOrigen,CampoDestino):
    Filas=df.shape[0]
    FilasRellenas=0
    for i in range(Filas):
        entero=df.loc[i,CampoOrigen]
        if entero==entero:
            cadena=diccionario[entero]
            df.loc[i,CampoDestino]=cadena
            FilasRellenas=FilasRellenas+1
    print("Filas = "+str(Filas))
    print("FilasRellenas = "+str(FilasRellenas))
    Ratio=FilasRellenas/Filas
    print("Ratio[%] = "+str(100*Ratio))
    print("-"*10)
    print(df[CampoDestino].value_counts(1))

# %%
TraduceAunqueHayaNaNs(df_hogares,OCUPAdict,'OCUPA','OcupacionSustentadorPrincipal')
# Out:
# Filas = 105436
# FilasRellenas = 101697
# Ratio[%] = 96.45377290489017
# ----------
# Trabajadores de los servicios de restauración, personales, protección y vendedores                                                             0.176141
# Artesanos y trabajadores cualificados de las industrias manufactureras y la construcción (excepto operadores de instalaciones y maquinaria)    0.167852
# Técnicos y profesionales científicos e intelectuales                                                                                           0.155167
# Ocupaciones elementales                                                                                                                        0.121724
# Técnicos y profesionales de apoyo                                                                                                              0.104044
# ...

# %% [markdown]
# ### OCUPARED

# %%
OCUPAREDdict={
1: 'Directores y gerentes',
2: 'Técnicos y profesionales',
3: 'Empleados de tipo administrativo y trabajadores de servicios y de comercio',
4: 'Artesanos y trabajadores cualificados de otros sectores, operadores y montadores',
5: 'Trabajadores en ocupaciones elementales',
-9: 'No consta o Fuerzas armadas' 
}

# %%
TraduceAunqueHayaNaNs(df_hogares,OCUPAREDdict,'OCUPARED','OcupacionSustentadorPrincipal_redux')
# Out:
# Filas = 105436
# FilasRellenas = 101697
# Ratio[%] = 96.45377290489017
# ----------
# Artesanos y trabajadores cualificados de otros sectores, operadores y montadores    0.313038
# Técnicos y profesionales                                                            0.259211
# Empleados de tipo administrativo y trabajadores de servicios y de comercio          0.254491
# Trabajadores en ocupaciones elementales                                             0.121724
# Directores y gerentes                                                               0.044701
# No consta o Fuerzas armadas                                                         0.006834
# Name: OcupacionSustentadorPrincipal_redux, dtype: float64

# %% [markdown]
# ### ACTESTB

# %%
ACTESTBdict={
'A': 'Agricultura, ganadería, silvicultura y pesca',
'B': 'Industrias extractivas',
'C': 'Industria manufacturera',
'D': 'Suministro de energía eléctrica, gas, vapor y aire acondicionado',
'E': 'Suministro de agua, saneamiento y gestión de residuos',
'F': 'Construcción',
'G': 'Comercio y reparación de vehículos de motor',
'H': 'Transporte y almacenamiento',
'I': 'Hostelería',
'J': 'Información y comunicaciones',
'K': 'Actividades financieras y de seguros',
'L': 'Actividades inmobiliarias',
'M': 'Actividades profesionales, científicas y técnicas',
'N': 'Actividades administrativas y servicios auxiliares',
'O': 'Administración pública y defensa; seguridad social obligatoria',
'P': 'Educación',
'Q': 'Actividades sanitarias y de servicios sociales',
'R': 'Actividades artísticas, recreativas y de entretenimiento',
'S': 'Otros servicios',
'T': 'Actividades de los hogares como empleadores de personal doméstico',
'-9': 'No consta (incluye actividades de organizaciones y organismos extraterritoriales)'
}

# %%
TraduceAunqueHayaNaNs(df_hogares,ACTESTBdict,'ACTESTB','Actividad')
# Out:
# Filas = 105436
# FilasRellenas = 101697
# Ratio[%] = 96.45377290489017
# ----------
# Industria manufacturera                                                              0.179838
# Comercio y reparación de vehículos de motor                                          0.127339
# Construcción                                                                         0.094231
# Administración pública y defensa; seguridad social obligatoria                       0.093149
# Agricultura, ganadería, silvicultura y pesca                                         0.068488
# Actividades sanitarias y de servicios sociales                                       0.062047
# Educación                                                                            0.060936
# Hostelería                                                                           0.059372
# Transporte y almacenamiento                                                          0.057121
# ...

# %% [markdown]
# ### ACTESTBRED

# %%
ACTESTBREDdict={
    1: 'Agricultura, ganadería, silvicultura y pesca',
    2: 'Industrias extractiva, manufacturera, eléctrica, gas, vapor y aire acondicionado, agua, saneamiento, gestión de residuos y descontaminación, construcción',
    3: 'Servicios',
    -9: 'No consta (incluye actividades de organizaciones y organismos extraterritoriales)',
    }

# %%
TraduceAunqueHayaNaNs(df_hogares,ACTESTBREDdict,'ACTESTBRED','Actividad_redux')
# Out:
# Filas = 105436
# FilasRellenas = 101697
# Ratio[%] = 96.45377290489017
# ----------
# Servicios                                                                                                                                                    0.637020
# Industrias extractiva, manufacturera, eléctrica, gas, vapor y aire acondicionado, agua, saneamiento, gestión de residuos y descontaminación, construcción    0.294168
# Agricultura, ganadería, silvicultura y pesca                                                                                                                 0.068488
# No consta (incluye actividades de organizaciones y organismos extraterritoriales)                                                                            0.000324
# Name: Actividad_redux, dtype: float64

# %% [markdown]
# ### SITPROF

# %%
SITPROFdict={
    1: 'Asalariado',
    2: 'Empresario sin asalariados o trabajador independiente',
    3: 'Empleador',
    4: 'Otra situación (ayuda familiar, etc.)',
    -9: 'No consta',
}

# %%
TraduceAunqueHayaNaNs(df_hogares,SITPROFdict,'SITPROF','SituacionProfesional')
# Out:
# Filas = 105436
# FilasRellenas = 101697
# Ratio[%] = 96.45377290489017
# ----------
# Asalariado                                               0.816769
# Empresario sin asalariados o trabajador independiente    0.127447
# Empleador                                                0.053935
# Otra situación (ayuda familiar, etc.)                    0.001829
# No consta                                                0.000020
# Name: SituacionProfesional, dtype: float64

# %% [markdown]
# ### SECTOR

# %%
SECTORdict={
    1: 'Público',
    6: 'Privado',
    -9: 'No consta',
}

# %%
df_hogares.SECTOR.value_counts()
# Out:
#  6.0    62301
#  1.0    20762
# -9.0    18634
# Name: SECTOR, dtype: int64

# %%
TraduceAunqueHayaNaNs(df_hogares,SECTORdict,'SECTOR','Sector')
# Out:
# Filas = 105436
# FilasRellenas = 101697
# Ratio[%] = 96.45377290489017
# ----------
# Privado      0.612614
# Público      0.204155
# No consta    0.183231
# Name: Sector, dtype: float64

# %%
del df_hogares['SECTOR']

# %% [markdown]
# ### CONTRATO

# %%
CONTRATOdict={
    1: 'Con contrato',
    6: 'Sin contrato',
    -9: 'No consta',
    }

# %%
TraduceAunqueHayaNaNs(df_hogares,CONTRATOdict,'CONTRATO','Contrato')
# Out:
# Filas = 105436
# FilasRellenas = 101697
# Ratio[%] = 96.45377290489017
# ----------
# Con contrato    0.799089
# No consta       0.183231
# Sin contrato    0.017680
# Name: Contrato, dtype: float64

# %%
del df_hogares['CONTRATO']

# %% [markdown]
# ### TIPOCONT

# %%
TIPOCONTdict={
    1: 'Indefinido',
    2: 'Temporal',
    -9: 'No consta',
}

# %%
TraduceAunqueHayaNaNs(df_hogares,TIPOCONTdict,'TIPOCONT','DuracionContrato')
# Out:
# Filas = 105436
# FilasRellenas = 99899
# Ratio[%] = 94.74847300732198
# ----------
# Indefinido    0.662039
# No consta     0.186528
# Temporal      0.151433
# Name: DuracionContrato, dtype: float64

# %% [markdown]
# ### SITSOCI

# %%
SITSOCIdict={
    1: 'Trabajador manual, excepto agricultura',
    2: 'Trabajador no manual, excepto agricultura',
    3: 'Trabajador manual, excepto agricultura',
    4: 'Trabajador no manual, excepto agricultura',
    5: 'Independiente, excepto agricultura',
    6: 'Agricultor independiente o trabajador de la agricultura',
    7: 'Parado/a',
    8: 'Jubilado/a, retirado/a anticipadamente',
    9: 'Estudiante',
    10: 'Labores del hogar o actividad no económica',
    11: 'Incapacitados para trabajar',
    -9: 'No consta'
}

# %%
Traduce(df_hogares,SITSOCIdict,'SITSOCI','SituacionSocial')
# Out:
# Jubilado/a, retirado/a anticipadamente                     0.299717
# Trabajador manual, excepto agricultura                     0.232416
# Trabajador no manual, excepto agricultura                  0.219564
# Independiente, excepto agricultura                         0.093953
# Parado/a                                                   0.059809
# Labores del hogar o actividad no económica                 0.059572
# Agricultor independiente o trabajador de la agricultura    0.027144
# Incapacitados para trabajar                                0.006829
# Estudiante                                                 0.000854
# No consta                                                  0.000142
# Name: SituacionSocial, dtype: float64

# %% [markdown]
# ### SITSOCIRE

# %%
SITSOCIREdict={
    1: 'Trabajador manual, excepto agricultura',
    2: 'Trabajador no manual, excepto agricultura',
    3: 'Trabajador independiente y agricultor o trabajador en la agricultura',
    4: 'Parado',
    5: 'Retirados o jubilados',
    6: 'Otros inactivos',
    -9: 'No consta'    
}

# %%
Traduce(df_hogares,SITSOCIREdict,'SITSOCIRE','SituacionSocial_redux')
# Out:
# Retirados o jubilados                                                   0.299717
# Trabajador manual, excepto agricultura                                  0.232416
# Trabajador no manual, excepto agricultura                               0.219564
# Trabajador independiente y agricultor o trabajador en la agricultura    0.121097
# Otros inactivos                                                         0.067254
# Parado                                                                  0.059809
# No consta                                                               0.000142
# Name: SituacionSocial_redux, dtype: float64

# %%
Tipos=df_hogares.dtypes
Tipos[84]
# Out:
# dtype('int64')

# %%
df_hogares['Ingresos Netos Anuales Hogar']=df_hogares['IMPEXAC']*12

# %%
df_hogares['Ingresos Netos Mensuales Hogar']=df_hogares['IMPEXAC']

# %%
df_hogares['Gastos Anuales Hogar']=df_hogares['GASTMON']/df_hogares['FACTOR']

# %%
df_hogares['Gastos Mensuales Hogar']=df_hogares['Gastos Anuales Hogar']/12

# %%
df_hogares['Ahorro Mensual Hogar']=df_hogares['Ingresos Netos Mensuales Hogar']-df_hogares['Gastos Mensuales Hogar']

# %%
df_hogares['Ahorro Anual Hogar']=df_hogares['Ingresos Netos Anuales Hogar']-df_hogares['Gastos Anuales Hogar']

# %%
#del df_hogares['Hogares']
df_hogares['Hogares']=df_hogares['FACTOR']

# %%
df_hogares
# Out:
#         ANOENC  NUMERO  CCAA     NUTS1  CAPROV  TAMAMU  DENSIDAD  CLAVE  \
# 0         2019       1     1       Sur       1       1         1      2
# 1         2019       2    13    Madrid       6       1         1      1
# 2         2019       3    15   NorEste       6       4         2      1
# 3         2019       4    16   NorEste       6       4         1      1
# 4         2019       5     3  NorOeste       6       4         3      2
# ...        ...     ...   ...       ...     ...     ...       ...    ...
# 105431    2020   19166     7    Centro       6       5         3      1
# 105432    2020   19167     9      Este       6       5         3      2
# 105433    2020   19168     9      Este       6       5         3      2
# 105434    2020   19169    10      Este       6       3         2      2
# 105435    2020   19170     7    Centro       1       1         1      1
#
#         CLATEO       FACTOR  ...  DuracionContrato  \
# ...

# %%
def DescribeDf(df):
    Columnas =df.columns
    Tipos=df.dtypes
    NumFilas=df.shape[0]
    NumColumnas=df.shape[1]
    print("Filas    = " +str(NumFilas))
    print("Columnas = " +str(NumColumnas))
    for i in range(NumColumnas):
        print('-'*50)
        print("Campo "+str(i+1)+'/'+str(NumColumnas)+" (Index "+str(i)+"): "+Columnas[i])
        print("")
        VC=df[Columnas[i]].value_counts()
        ValoresDistintos=VC.shape[0]
        if ValoresDistintos<=40:
            print(VC)
        elif ValoresDistintos==NumFilas:
            print("   >>> Posible clave principal <<<")
            print("")
            VC=df[Columnas[i]].value_counts(bins=10)
            print(VC)
        elif Tipos[i]=='int64' or Tipos[i]=='float64':
            print("ValoresDistintos="+str(NumFilas))
            print("")
            VC=df[Columnas[i]].value_counts(bins=10)
            print(VC)

# %%
DescribeDf(df_hogares)
# Out:
# Filas    = 105436
# Columnas = 215
# --------------------------------------------------
# Campo 1/215 (Index 0): ANOENC
#
# 2017    22043
# 2016    22011
# 2018    21395
# 2019    20817
# 2020    19170
# Name: ANOENC, dtype: int64
# --------------------------------------------------
# Campo 2/215 (Index 1): NUMERO
#
# ValoresDistintos=105436
#
# (8817.8, 11022.0]                11025
# (-21.043000000000003, 2205.2]    11025
# (15430.4, 17634.6]               11020
# (13226.2, 15430.4]               11020
# (11022.0, 13226.2]               11020
# (6613.6, 8817.8]                 11020
# (4409.4, 6613.6]                 11020
# (2205.2, 4409.4]                 11020
# (17634.6, 19838.8]               10352
# (19838.8, 22043.0]                6914
# Name: NUMERO, dtype: int64
# --------------------------------------------------
# Campo 3/215 (Index 2): CCAA
#
# 1     11465
# 16    10913
# 9      9521
# 10     8326
# 13     7876
# 7      6875
# 12     6601
# 8      5675
# 5      4812
# ...

# %%
df_hogares.head()
# Out:
#    ANOENC  NUMERO  CCAA     NUTS1  CAPROV  TAMAMU  DENSIDAD  CLAVE  CLATEO  \
# 0    2019       1     1       Sur       1       1         1      2       2
# 1    2019       2    13    Madrid       6       1         1      1       2
# 2    2019       3    15   NorEste       6       4         2      1       2
# 3    2019       4    16   NorEste       6       4         1      1       1
# 4    2019       5     3  NorOeste       6       4         3      2       2
#
#         FACTOR  ...  DuracionContrato  \
# 0  1294.618356  ...         No consta
# 1  1569.018845  ...        Indefinido
# 2   332.468410  ...               NaN
# 3   311.734979  ...        Indefinido
# 4   524.758178  ...        Indefinido
#
#                               SituacionSocial  \
# 0          Independiente, excepto agricultura
# 1      Jubilado/a, retirado/a anticipadamente
# 2  Labores del hogar o actividad no económica
# 3      Trabajador manual, excepto agricultura
# ...

# %%
df_hogares.to_csv(r'../../03_Tablas/hogares.csv',index=False)

# %%
df_hogares['GASTMON'].sum()/pow(10,6)
# Out:
# 2122298.23164839

# %%
df_hogares['IMPEXAC'].mean()
# Out:
# 2140.471508782579
